# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
import pandas as pd
import requests

# %%
# 1) 
pvl_rj = 'http://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Município'

# %%
r = requests.get(pvl_rj)

# %%
r.status_code
# Out:
# 200

# %%
data_json = r.json()

# %%
print(data_json['items'])
# Out:
# [{'id_pleito': 12014, 'tipo_interessado': 'Município', 'interessado': 'Cardoso Moreira', 'cod_ibge': 3301157, 'uf': 'RJ', 'num_pvl': None, 'status': 'Arquivado', 'num_processo': '17944.001581/2009-96', 'data_protocolo': '2010-05-07T00:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Caminho da Escola 2009 A', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco do Brasil S/A', 'moeda': 'Real', 'valor': 995000, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 0, 'data_status': '21/12/2010'}, {'id_pleito': 13753, 'tipo_interessado': 'Município', 'interessado': 'Piraí', 'cod_ibge': 3304003, 'uf': 'RJ', 'num_pvl': None, 'status': 'Deferido', 'num_processo': '19405.000071/2002-58', 'data_protocolo': '2002-09-30T00:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'PMAT', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco Nacional de Desenvolvimento Econômico e Social', 'moeda': 'Real', 'valor': 408600, 'pvl_assoc_div
# ...

# %%
# Criação do DataFrame
df = pd.DataFrame(data_json['items'])
df
# Out:
#      id_pleito tipo_interessado      interessado  cod_ibge  uf  \
# 0        12014        Município  Cardoso Moreira   3301157  RJ
# 1        13753        Município            Piraí   3304003  RJ
# 2        13579        Município   Rio de Janeiro   3304557  RJ
# 3        13817        Município          Valença   3306107  RJ
# 4        34100        Município          Resende   3304201  RJ
# ..         ...              ...              ...       ...  ..
# 277      22824        Município   Rio de Janeiro   3304557  RJ
# 278      42252        Município         Itatiaia   3302254  RJ
# 279      71604        Município           Maricá   3302700  RJ
# 280      38893        Município  Paty do Alferes   3303856  RJ
# 281      28822        Município          Resende   3304201  RJ
#
#                   num_pvl                                             status  \
# 0                    None                                          Arquivado
# ...

# %%
# Substituindo valores None da coluna num_pvl

df['num_pvl'] = df['num_pvl'].fillna('Não informado')
df
# Out:
#      id_pleito tipo_interessado      interessado  cod_ibge  uf  \
# 0        12014        Município  Cardoso Moreira   3301157  RJ
# 1        13753        Município            Piraí   3304003  RJ
# 2        13579        Município   Rio de Janeiro   3304557  RJ
# 3        13817        Município          Valença   3306107  RJ
# 4        34100        Município          Resende   3304201  RJ
# ..         ...              ...              ...       ...  ..
# 277      22824        Município   Rio de Janeiro   3304557  RJ
# 278      42252        Município         Itatiaia   3302254  RJ
# 279      71604        Município           Maricá   3302700  RJ
# 280      38893        Município  Paty do Alferes   3303856  RJ
# 281      28822        Município          Resende   3304201  RJ
#
#                   num_pvl                                             status  \
# 0           Não informado                                          Arquivado
# ...

# %%
# 2) Quais são os três status das solicitações mais frequentes na base? Quais são suas frequências?
# Usando .value_counts() e .head(3) para limitar o resultado aos 3 mais frequentes

status_frequentes = df['status'].value_counts().head(3)

print("Os 3 status de solicitação mais frequentes são:")
print(status_frequentes)
# Out:
# Os 3 status de solicitação mais frequentes são:
# status
# Deferido             106
# Arquivado             53
# Deferido (PVL-IF)     26
# Name: count, dtype: int64

# %%
# 3) Construindo a variável que contenha o ano do status

df['ano_status'] = df['data_status'].str.slice(6, 10)

print(f"O ano de cada status é:\n ano_status") 
print(df['ano_status'])
# Out:
# O ano de cada status é:
#  ano_status
# 0      2010
# 1      2002
# 2      2007
# 3      2006
# 4      2019
#        ...
# 277    2016
# 278    2020
# 279    2025
# 280    2019
# 281    2018
# Name: ano_status, Length: 282, dtype: object

# %%
# 4) Frequência de cada ano na coluna ano_status

frequencia_ano_status = df['ano_status'].value_counts()

print("Frequência das solicitações por ano:\n")
print(frequencia_ano_status)
# Out:
# Frequência das solicitações por ano:
#
# ano_status
# 2008    37
# 2007    29
# 2023    28
# 2014    20
# 2010    19
# 2025    17
# 2019    16
# 2013    15
# 2020    14
# 2012    13
# 2022    11
# 2011    10
# 2009     9
# 2024     8
# 2015     8
# 2017     5
# 2021     5
# 2006     4
# 2002     4
# 2018     4
# 2016     4
# 2003     1
# 2004     1
# Name: count, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
# 1) Função em Python

def filtro_uf_tipo(uf: str, tipo_interessado: str):
    url_completa = f'http://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf={uf}&tipo_interessado={tipo_interessado}'
    
    response = requests.get(url_completa)
    data = response.json()
    df = pd.DataFrame(data['items'])

    # Filtrando UF e tipo interessado (Estado ou Município)
    filtro = (df['uf'] == uf) & (df['tipo_interessado'] == tipo_interessado)
    df_filtrado = df[filtro]

    return df_filtrado

# %%
# 2) Consulta de status em 'Arquivado por decurso de prazo' para MG

uf = 'MG'
tipo_interessado = 'Estado'

df_filtrado = filtro_uf_tipo(uf, tipo_interessado)

df_arquivado = df_filtrado[df_filtrado['status'] == 'Arquivado por decurso de prazo']

quantidade_arquivado = df_arquivado.shape[0]

print(f"A quantidade de status 'Arquivado por decurso de prazo' para {tipo_interessado} de {uf} é: {quantidade_arquivado}")
# Out:
# A quantidade de status 'Arquivado por decurso de prazo' para Estado de MG é: 1

# %%
# 3) Município da Bahia com mais solicitações deferidas

uf = 'BA'
tipo_interessado = 'Município'
url_completa = f'http://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf={uf}&tipo_interessado={tipo_interessado}'

# Requisição à API
response = requests.get(url_completa)
data = response.json()
df = pd.DataFrame(data['items'])

# Verificar as colunas disponíveis no DataFrame
# print(df.columns)

#Filtro para deferidos
df_deferido = df[df['status'] == 'Deferido']

municipio_mais_frequente = df_deferido['interessado'].value_counts().head(1)

print(f"O município da Bahia com mais solicitações deferidas é:")
print(municipio_mais_frequente)
# Out:
# O município da Bahia com mais solicitações deferidas é:
# interessado
# Luís Eduardo Magalhães    16
# Name: count, dtype: int64

# %%
# 4) Salvando os dados de solicitações da Bahia, com interessado = 'Estado' em um arquivo .csv

uf = 'BA'
tipo_interessado = 'Estado'
url_completa = f'http://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf={uf}&tipo_interessado={tipo_interessado}'

# Requisição à API e criação do DataFrame
response = requests.get(url_completa)
data = response.json()
df_bahia_estado = pd.DataFrame(data['items'])

# Salvando o DataFrame em um arquivo CSV
nome_arquivo = 'solicitacoes_bahia.csv'
df_bahia_estado.to_csv(nome_arquivo, index=False) # index=False evita que o índice numérico do DataFrame seja salvo como uma coluna no CSV.

# Conferindo as primeiras linhas do DataFrame que foi salvo
print("\nPrimeiras 5 linhas do DataFrame salvo:")
print(df_bahia_estado.head())
# Out:
# Primeiras 5 linhas do DataFrame salvo:
#    id_pleito tipo_interessado interessado  cod_ibge  uf               num_pvl  \
# 0      12991           Estado       Bahia        29  BA                  None
# 1      23723           Estado       Bahia        29  BA  PVL02.000640/2016-75
# 2      64646           Estado       Bahia        29  BA  PVL02.000882/2023-98
# 3       8733           Estado       Bahia        29  BA                  None
# 4      10659           Estado       Bahia        29  BA                  None
#
#                                               status          num_processo  \
# 0  Encaminhado à PGFN com manifestação técnica fa...  17944.001875/2008-37
# 1  Encaminhado à PGFN com manifestação técnica fa...  17944.001273/2016-90
# 2  Encaminhado à PGFN com manifestação técnica fa...  17944.102176/2023-42
# 3  Encaminhado à PGFN com manifestação técnica fa...  17944.000833/2010-01
# 4  Encaminhado à PGFN com manifestação técnica fa...  17944.001253/2012-95
#
# ...
